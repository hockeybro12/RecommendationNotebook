# %%
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_csv("ratings_Grocery_and_Gourmet_Food.csv", sep = ",", header=None, names=['User', 'Item', 'Rating', 'Timestamps'])

print("There are %d rows in this dataframe" %len(data))

data.head()
# Out:
# There are 1297156 rows in this dataframe
#              User        Item  Rating  Timestamps
# 0  A1ZQZ8RJS1XVTX  0657745316     5.0  1381449600
# 1  A31W38VGZAUUM4  0700026444     5.0  1354752000
# 2  A3I0AV0UJX5OH0  1403796890     1.0  1385942400
# 3  A3QAAOLIXKV383  1403796890     3.0  1307836800
# 4   AB1A5EGHHVA9M  141278509X     5.0  1332547200

# %%
top_items = pd.value_counts(data.Item)
top_items.head(20)
# Out:
# B0051SU0OW    6340
# B00DS842HS    3755
# B000E1D7RS    3102
# B0029XDZIK    3011
# B005K4Q1YA    3000
# B0015KAYN2    2740
# B008I1XLDQ    2731
# B007TGDXMU    2452
# B007Y59HVM    2394
# B0010YA02S    2371
# B0031JK95S    2220
# B001D0GV4K    2096
# B001EO5Q64    1899
# B005K4Q1T0    1838
# B000GFYRHG    1765
# B00BI8OG2Q    1688
# B001D05RWC    1658
# B00032G1S0    1628
# B007TGDXNO    1585
# B003D4F18G    1583
# Name: Item, dtype: int64

# %%
top_reviewers = pd.value_counts(data.User)
top_reviewers.head(20)
# Out:
# AY12DBB0U420B     518
# A1LACH6MLQWZ      490
# A3D6OI36USYOU1    440
# A2NYK9KWFMJV4Y    432
# A3OXHLG6DIBRW8    378
# A281NPSIMI1C2R    335
# A1GQAKL9CGQLP1    332
# A2XKJ1KX6XUHYP    315
# A1Z54EM24Y40LL    285
# A2MUGFV2TDQ47K    265
# A2M9D9BDHONV3Y    233
# A1UQBFCERIP7VJ    231
# A2MNB77YGJ3CN0    229
# A14BTJRH9VNLJJ    225
# A1X1CEGHTHMBL1    219
# A36MP37DITBU6F    215
# ALSAOZ1V546VT     212
# A2C9XE9I8RSKNX    208
# AQQLWCMRNDFGI     208
# A1WX42M589VAMQ    206
# Name: User, dtype: int64

# %%
# Let's create a function that collect the reviews of our common reviewers
def get_book_reviews(title, common_reviewers):
    mask = (data.User.isin(common_reviewers)) & (data.Item==title)
    reviews = data[mask].sort_values(by='User')
    reviews = reviews[reviews.User.duplicated()==False]
    return reviews

# %%
item_1, item_2 = "B001SB2SGO", "B001TJPM0O"

item_1_reviewers = data[data.Item == item_1].User
item_2_reviewers = data[data.Item == item_2].User

common_reviewers = set(item_1_reviewers).intersection(item_2_reviewers)

print("%d people have reviewed these items" % len(common_reviewers))

# Checking the table with only the common reviewers
list_common_reviewers = []

for i in common_reviewers:
    list_common_reviewers.append(i)

common_reviewers_only = data[data.User.isin(list_common_reviewers)]

common_reviewers_only.head(10)
# Out:
# 1 people have reviewed these items
#                User        Item  Rating  Timestamps
# 1961   A1LACH6MLQWZ  B0000CCZYY     5.0  1399075200
# 8036   A1LACH6MLQWZ  B0000DIYKH     5.0  1385683200
# 8066   A1LACH6MLQWZ  B0000DIYVC     5.0  1398124800
# 8126   A1LACH6MLQWZ  B0000DIYWP     5.0  1398470400
# 11926  A1LACH6MLQWZ  B0000TI4L8     5.0  1403654400
# 20402  A1LACH6MLQWZ  B00016LA7U     5.0  1402358400
# 21429  A1LACH6MLQWZ  B00016V25A     5.0  1399334400
# 21434  A1LACH6MLQWZ  B00016V26O     5.0  1399420800
# 21456  A1LACH6MLQWZ  B00016V282     5.0  1399420800
# 25410  A1LACH6MLQWZ  B0001DMSW4     5.0  1404432000

# %%
# Importing the scipy library to measure the pearson correlation coefficient
from scipy.stats.stats import pearsonr

def calculate_correlation(book1, book2):
    # We start by finding the common reviewers
    book_1_reviewers = data[data.Item == book1].User
    book_2_reviewers = data[data.Item == book2].User
    common_reviewers = set(book_1_reviewers).intersection(book_2_reviewers)

    # Then we look for the reviews given by common reviewers
    book_1_reviews = get_book_reviews(book1, common_reviewers)
    book_2_reviews = get_book_reviews(book2, common_reviewers)
        
    # Calculate the Pearson Correlation Score
    return pearsonr(book_1_reviews.Rating, book_2_reviews.Rating)[0]

# Print the correlation score
calculate_correlation(item_1,item_2)
# Out:
# nan

# %%
most_reviewed_books = pd.DataFrame({'count' : data.groupby(["Item"]).size()})\
                                    .reset_index().sort_values(by = ['count'],ascending = False)

most_reviewed_books.head(40)
# Out:
#               Item  count
# 96463   B0051SU0OW   6340
# 151070  B00DS842HS   3755
# 10790   B000E1D7RS   3102
# 57073   B0029XDZIK   3011
# 103055  B005K4Q1YA   3000
# 35030   B0015KAYN2   2740
# 124594  B008I1XLDQ   2731
# 118613  B007TGDXMU   2452
# 119549  B007Y59HVM   2394
# 32570   B0010YA02S   2371
# 64917   B0031JK95S   2220
# 39209   B001D0GV4K   2096
# 41224   B001EO5Q64   1899
# 103053  B005K4Q1T0   1838
# 16180   B000GFYRHG   1765
# 141069  B00BI8OG2Q   1688
# 39176   B001D05RWC   1658
# 5796    B00032G1S0   1628
# 118614  B007TGDXNO   1585
# 68054   B003D4F18G   1583
# 3537    B0001EQN88   1581
# 21660   B000LKXRNQ   1561
# 103040  B005K0L2U2   1427
# 59343   B002HQCWYM   1351
# 26202   B000PDWBKO   1315
# 10183   B000CN7BMA   1285
# 38981   B001CHFUDC   1211
# 57097   B0029XLH4Y   1166
# 14430   B000FEH8ME   1124
# 116923  B007N04AF6   1106
# 75233   B003Z6W32E   1095
# 101903  B005HGAVD8    994
# 15984   B000GAT6NG    979
# 56401   B0029AG878    966
# 143742  B00C1LXBFC    966
# 88838   B004M62D5S    964
# 12230   B000ENUC3S    960
# 24608   B000NMJWZO    959
# 70069   B003KRHDMI    952
# 65649   B0034EDLS2    945

# %%
# Getting the list of the most reviewed book

top_books = []

for i in most_reviewed_books.Item[0:100]:
    top_books.append(i)

    
# calculate the correlation for our top books
correlation_coefficient = []

for book1 in top_books:
    print("Calculating the correlations for:", book1)
    for book2 in top_books:
        if book1 != book2:
            row = [book1, book2] + [calculate_correlation(book1, book2)]
            correlation_coefficient.append(row)
# Out:
# Calculating the correlations for: B0051SU0OW
# //anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Calculating the correlations for: B00DS842HS
# Calculating the correlations for: B000E1D7RS
# Calculating the correlations for: B0029XDZIK
# Calculating the correlations for: B005K4Q1YA
# Calculating the correlations for: B0015KAYN2
# Calculating the correlations for: B008I1XLDQ
# Calculating the correlations for: B007TGDXMU
# Calculating the correlations for: B007Y59HVM
# Calculating the correlations for: B0010YA02S
# Calculating the correlations for: B0031JK95S
# Calculating the correlations for: B001D0GV4K
# Calculating the correlations for: B001EO5Q64
# Calculating the correlations for: B005K4Q1T0
# Calculating the correlations for: B000GFYRHG
# Calculating the correlations for: B00BI8OG2Q
# Calculating the correlations for: B001D05RWC
# Calculating the correlations for: B00032G1S0
# Calculating the correlations for: B007TGDXNO
# Calculating the correlations for: B003D4F18G
# Calculating the correlations for: B0001EQN88
# Calculating the correlations for: B000LKXRNQ
# Calculating the correlations for: B005K0L2U2
# Calculating the correlations for: B002HQCWYM
# Calculating the correlations for: B000PDWBKO
# Calculating the correlations for: B000CN7BMA
# Calculating the correlations for: B001CHFUDC
# Calculating the correlations for: B0029XLH4Y
# Calculating the correlations for: B000FEH8ME
# Calculating the correlations for: B007N04AF6
# Calculating the correlations for: B003Z6W32E
# Calculating the correlations for: B005HGAVD8
# Calculating the correlations for: B000GAT6NG
# Calculating the correlations for: B0029AG878
# Calculating the correlations for: B00C1LXBFC
# Calculating the correlations for: B004M62D5S
# Calculating the correlations for: B000ENUC3S
# Calculating the correlations for: B000NMJWZO
# Calculating the correlations for: B003KRHDMI
# Calculating the correlations for: B0034EDLS2
# Calculating the correlations for: B002IEVJRY
# Calculating the correlations for: B000VK4DXO
# Calculating the correlations for: B005KK56JU
# Calculating the correlations for: B003OGKCDC
# Calculating the correlations for: B0029XDZKI
# Calculating the correlations for: B001D0IZBM
# Calculating the correlations for: B005ZBZLT4
# Calculating the correlations for: B008XFE2YO
# Calculating the correlations for: B000F4DKAI
# Calculating the correlations for: B0007NOWMM
# Calculating the correlations for: B000R71WMQ
# Calculating the correlations for: B00014CZP8
# Calculating the correlations for: B0010UOGWM
# Calculating the correlations for: B0043WOANY
# Calculating the correlations for: B000EVOSE4
# Calculating the correlations for: B003OZV4Y4
# Calculating the correlations for: B000EVQWKC
# Calculating the correlations for: B0027Z5J6G
# Calculating the correlations for: B000Z93FQC
# Calculating the correlations for: B004P4POZ8
# Calculating the correlations for: B004TJF39Q
# Calculating the correlations for: B003TBRF1O
# Calculating the correlations for: B0098WV8F2
# Calculating the correlations for: B00BP36RTY
# Calculating the correlations for: B001E0HT2W
# Calculating the correlations for: B004391DK0
# Calculating the correlations for: B003Z6ZGZU
# Calculating the correlations for: B009AH7OU8
# Calculating the correlations for: B00GW3KSPQ
# Calculating the correlations for: B003QDRJXY
# Calculating the correlations for: B007TGDXMK
# Calculating the correlations for: B001ELL60W
# Calculating the correlations for: B007OSBE1U
# Calculating the correlations for: B000UP8QQ0
# Calculating the correlations for: B00C7MGHVA
# Calculating the correlations for: B001E5E2RC
# Calculating the correlations for: B005HG9ERW
# Calculating the correlations for: B00DDT116M
# Calculating the correlations for: B001BM4JLC
# Calculating the correlations for: B000SDIO3E
# Calculating the correlations for: B001CGTN1I
# Calculating the correlations for: B0032RPLSY
# Calculating the correlations for: B0012C2GFM
# Calculating the correlations for: B006IOKA9S
# Calculating the correlations for: B00CVTFT6I
# Calculating the correlations for: B00ABKWSTA
# Calculating the correlations for: B0045Z6K50
# Calculating the correlations for: B003FDC2I2
# Calculating the correlations for: B000UUWECC
# Calculating the correlations for: B00HK6FGIS
# Calculating the correlations for: B00DSQZNEG
# Calculating the correlations for: B000VK08OC
# Calculating the correlations for: B000K8WVYA
# Calculating the correlations for: B000H7LVKY
# Calculating the correlations for: B004538TME
# Calculating the correlations for: B0026ZYZ7Q
# Calculating the correlations for: B003YBH398
# Calculating the correlations for: B0014WYXQK
# Calculating the correlations for: B001XUIGG6
# Calculating the correlations for: B0008D6WBA

# %%
# Let's look at what the table of correlation looks like
cols = ["Item_1", "Item_2", "Correlation"]
correlation_coefficient = pd.DataFrame(correlation_coefficient, columns=cols).sort('Correlation')
correlation_coefficient.head(10)
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#           Item_1      Item_2  Correlation
# 6737  B00GW3KSPQ  B0015KAYN2         -1.0
# 5553  B000EVQWKC  B0010YA02S         -1.0
# 6717  B009AH7OU8  B00ABKWSTA         -1.0
# 3750  B000NMJWZO  B000UUWECC         -1.0
# 8544  B0045Z6K50  B003Z6W32E         -1.0
# 369   B0029XDZIK  B000UP8QQ0         -1.0
# 3871  B0034EDLS2  B0031JK95S         -1.0
# 8482  B00ABKWSTA  B009AH7OU8         -1.0
# 8456  B00ABKWSTA  B000VK4DXO         -1.0
# 3914  B0034EDLS2  B000EVOSE4         -1.0

# %%
def calc_correlation(corr, book1, book2):
    mask = (corr.Item_1==book1) & (corr.Item_2==book2)
    row = corr[mask]
    corr = row
    return corr.sum(axis=1).tolist()[0]

# %%
calc_correlation(correlation_coefficient,"B0010YA02S", "B008I1XLDQ")
# Out:
# -0.57735026918962584

# %%
my_item = "B0051SU0OW"
results = []
for b in top_books:
    if my_item!=b:
        results.append((my_item, b, calc_correlation(correlation_coefficient, my_item, b)))
sorted(results, key=lambda x: x[2], reverse=True)
# Out:
# [('B0051SU0OW', 'B007N04AF6', 1.0),
#  ('B0051SU0OW', 'B005KK56JU', 1.0),
#  ('B0051SU0OW', 'B000F4DKAI', 1.0),
#  ('B0051SU0OW', 'B000VK08OC', 1.0),
#  ('B0051SU0OW', 'B003OZV4Y4', 0.87831006565367997),
#  ('B0051SU0OW', 'B001E5E2RC', 0.875),
#  ('B0051SU0OW', 'B000LKXRNQ', 0.87208159927238094),
#  ('B0051SU0OW', 'B0015KAYN2', 0.53300179088902611),
#  ('B0051SU0OW', 'B008XFE2YO', 0.46911839730040156),
#  ('B0051SU0OW', 'B007TGDXMK', 0.44268015435926766),
#  ('B0051SU0OW', 'B0010UOGWM', 0.41221726907430378),
#  ('B0051SU0OW', 'B004TJF39Q', 0.4036839258133284),
#  ('B0051SU0OW', 'B004538TME', 0.38760126648920734),
#  ('B0051SU0OW', 'B005HGAVD8', 0.37386963155028874),
#  ('B0051SU0OW', 'B005K0L2U2', 0.34519948546390994),
#  ('B0051SU0OW', 'B003Z6ZGZU', 0.33816225564196212),
#  ('B0051SU0OW', 'B0014WYXQK', 0.2711630722733202),
#  ('B0051SU0OW', 'B005K4Q1T0', 0.26649502619718712),
#  ('B0051SU0OW', 'B002HQCWYM', 0.25267634667287536),
#  ('B0051SU0OW', 'B005K4Q1YA', 0.25116811447584242),
#  ('B0051SU0OW', 'B000FEH8ME', 0.24999999999999997),
#  ('B0051SU0OW', 'B003KRHDMI', 0.23865290910646464),
#  ('B0051SU0OW', 'B0045Z6K50', 0.22184061271314914),
#  ('B0051SU0OW', 'B005ZBZLT4', 0.21669968899708958),
#  ('B0051SU0OW', 'B006IOKA9S', 0.2122647413031675),
#  ('B0051SU0OW', 'B0001EQN88', 0.17407765595569785),
#  ('B0051SU0OW', 'B004P4POZ8', 0.16666666666666663),
#  ('B0051SU0OW', 'B0029XDZIK', 0.15990482293796096),
#  ('B0051SU0OW', 'B0031JK95S', 0.14002800840280097),
#  ('B0051SU0OW', 'B0029XLH4Y', 0.095898011300696806),
#  ('B0051SU0OW', 'B001D0GV4K', 0.091133550442351441),
#  ('B0051SU0OW', 'B007Y59HVM', 0.090363274470708257),
#  ('B0051SU0OW', 'B007OSBE1U', 0.069495285696276568),
#  ('B0051SU0OW', 'B008I1XLDQ', 0.059106706451599232),
#  ('B0051SU0OW', 'B000E1D7RS', 0.048409585656502871),
#  ('B0051SU0OW', 'B00DS842HS', 0.0),
#  ('B0051SU0OW', 'B001EO5Q64', 0.0),
#  ('B0051SU0OW', 'B00BI8OG2Q', 0.0),
#  ('B0051SU0OW', 'B00032G1S0', 0.0),
#  ('B0051SU0OW', 'B000PDWBKO', 0.0),
#  ('B0051SU0OW', 'B000CN7BMA', 0.0),
#  ('B0051SU0OW', 'B000GAT6NG', 0.0),
#  ('B0051SU0OW', 'B0029AG878', 0.0),
#  ('B0051SU0OW', 'B00C1LXBFC', 0.0),
#  ('B0051SU0OW', 'B000ENUC3S', 0.0),
#  ('B0051SU0OW', 'B000NMJWZO', 0.0),
#  ('B0051SU0OW', 'B0034EDLS2', 0.0),
#  ('B0051SU0OW', 'B003OGKCDC', 0.0),
#  ('B0051SU0OW', 'B0043WOANY', 0.0),
#  ('B0051SU0OW', 'B000EVOSE4', 0.0),
#  ('B0051SU0OW', 'B000EVQWKC', 0.0),
#  ('B0051SU0OW', 'B000Z93FQC', 0.0),
#  ('B0051SU0OW', 'B0098WV8F2', 0.0),
#  ('B0051SU0OW', 'B00BP36RTY', 0.0),
#  ('B0051SU0OW', 'B001E0HT2W', 0.0),
#  ('B0051SU0OW', 'B004391DK0', 0.0),
#  ('B0051SU0OW', 'B009AH7OU8', 0.0),
#  ('B0051SU0OW', 'B00GW3KSPQ', 0.0),
#  ('B0051SU0OW', 'B003QDRJXY', 0.0),
#  ('B0051SU0OW', 'B001ELL60W', 0.0),
#  ('B0051SU0OW', 'B000UP8QQ0', 0.0),
#  ('B0051SU0OW', 'B00DDT116M', 0.0),
#  ('B0051SU0OW', 'B001BM4JLC', 0.0),
#  ('B0051SU0OW', 'B000SDIO3E', 0.0),
#  ('B0051SU0OW', 'B001CGTN1I', 0.0),
#  ('B0051SU0OW', 'B0032RPLSY', 0.0),
#  ('B0051SU0OW', 'B0012C2GFM', 0.0),
#  ('B0051SU0OW', 'B00CVTFT6I', 0.0),
#  ('B0051SU0OW', 'B003FDC2I2', 0.0),
#  ('B0051SU0OW', 'B000UUWECC', 0.0),
#  ('B0051SU0OW', 'B00HK6FGIS', 0.0),
#  ('B0051SU0OW', 'B00DSQZNEG', 0.0),
#  ('B0051SU0OW', 'B000K8WVYA', 0.0),
#  ('B0051SU0OW', 'B000H7LVKY', 0.0),
#  ('B0051SU0OW', 'B0026ZYZ7Q', 0.0),
#  ('B0051SU0OW', 'B001XUIGG6', 0.0),
#  ('B0051SU0OW', 'B0008D6WBA', 0.0),
#  ('B0051SU0OW', 'B0010YA02S', -0.017436851272653913),
#  ('B0051SU0OW', 'B001CHFUDC', -0.019199342168817753),
#  ('B0051SU0OW', 'B001D05RWC', -0.034836650714580891),
#  ('B0051SU0OW', 'B003TBRF1O', -0.052876264501413868),
#  ('B0051SU0OW', 'B000GFYRHG', -0.059005294323649496),
#  ('B0051SU0OW', 'B004M62D5S', -0.05977922455092128),
#  ('B0051SU0OW', 'B00ABKWSTA', -0.090909090909090912),
#  ('B0051SU0OW', 'B0027Z5J6G', -0.10223972648864955),
#  ('B0051SU0OW', 'B007TGDXNO', -0.10841979777728938),
#  ('B0051SU0OW', 'B007TGDXMU', -0.11525347104689769),
#  ('B0051SU0OW', 'B003D4F18G', -0.13363062095621214),
#  ('B0051SU0OW', 'B00C7MGHVA', -0.186113528638085),
#  ('B0051SU0OW', 'B001D0IZBM', -0.19556843291336984),
#  ('B0051SU0OW', 'B003Z6W32E', -0.24019223070763066),
#  ('B0051SU0OW', 'B003YBH398', -0.33333333333333331),
#  ('B0051SU0OW', 'B0029XDZKI', -0.38016544953902048),
#  ('B0051SU0OW', 'B002IEVJRY', -0.38510399211870394),
#  ('B0051SU0OW', 'B000R71WMQ', -0.40147753427348315),
#  ('B0051SU0OW', 'B000VK4DXO', -0.46153846153846151),
#  ('B0051SU0OW', 'B00014CZP8', -0.49999999999999994),
#  ('B0051SU0OW', 'B0007NOWMM', -0.52878317908707817),
#  ('B0051SU0OW', 'B005HG9ERW', -0.54470477940192219)]

# %%
def predict(self, my_book):
        results = []
        for other_book in self.top_books:
            if my_book != other_book:
                correlation = calc_correlation(self.correlation_coefficient, my_book, other_book)
                results.append((my_book, other_book, correlation)) 
        return sorted(results, key=lambda x: x[2], reverse=True)

# %%
def prediction(my_item):
    results = []
    for b in top_books:
        if my_item!=b:
            results.append((my_item, b, calc_correlation(correlation_coefficient, my_item, b)))
    return sorted(results, key=lambda x: x[2], reverse=True)

# %%
prediction("B008I1XLDQ")
# Out:
# [('B008I1XLDQ', 'B000F4DKAI', 1.0),
#  ('B008I1XLDQ', 'B0007NOWMM', 1.0),
#  ('B008I1XLDQ', 'B000R71WMQ', 1.0),
#  ('B008I1XLDQ', 'B0027Z5J6G', 1.0),
#  ('B008I1XLDQ', 'B003YBH398', 0.99999999999999989),
#  ('B008I1XLDQ', 'B005KK56JU', 0.96558102873057594),
#  ('B008I1XLDQ', 'B003OZV4Y4', 0.77491694904398156),
#  ('B008I1XLDQ', 'B004538TME', 0.77139253277983122),
#  ('B008I1XLDQ', 'B003D4F18G', 0.61237243569579458),
#  ('B008I1XLDQ', 'B0029XDZKI', 0.59233942641578774),
#  ('B008I1XLDQ', 'B000CN7BMA', 0.5222329678670935),
#  ('B008I1XLDQ', 'B000FEH8ME', 0.49414359250244588),
#  ('B008I1XLDQ', 'B007TGDXMK', 0.43441636322431459),
#  ('B008I1XLDQ', 'B0045Z6K50', 0.42260569821229232),
#  ('B008I1XLDQ', 'B003TBRF1O', 0.35404225536669398),
#  ('B008I1XLDQ', 'B004TJF39Q', 0.30769983137545265),
#  ('B008I1XLDQ', 'B004M62D5S', 0.289308582340706),
#  ('B008I1XLDQ', 'B001CHFUDC', 0.28473029832044183),
#  ('B008I1XLDQ', 'B005HG9ERW', 0.27463449890578462),
#  ('B008I1XLDQ', 'B001D0GV4K', 0.25085490599350074),
#  ('B008I1XLDQ', 'B002IEVJRY', 0.22385735071527146),
#  ('B008I1XLDQ', 'B0029XLH4Y', 0.21635433869101031),
#  ('B008I1XLDQ', 'B005K4Q1T0', 0.21423875104558496),
#  ('B008I1XLDQ', 'B007TGDXNO', 0.20639460980933153),
#  ('B008I1XLDQ', 'B0015KAYN2', 0.20519567041703077),
#  ('B008I1XLDQ', 'B002HQCWYM', 0.18106271051942241),
#  ('B008I1XLDQ', 'B007OSBE1U', 0.17651131065148987),
#  ('B008I1XLDQ', 'B008XFE2YO', 0.16182267881254694),
#  ('B008I1XLDQ', 'B001D0IZBM', 0.16023089886141131),
#  ('B008I1XLDQ', 'B005K4Q1YA', 0.15014755050872811),
#  ('B008I1XLDQ', 'B00C7MGHVA', 0.13191571495785792),
#  ('B008I1XLDQ', 'B0001EQN88', 0.12862393885688164),
#  ('B008I1XLDQ', 'B005ZBZLT4', 0.12018378293842205),
#  ('B008I1XLDQ', 'B007Y59HVM', 0.11216338683160917),
#  ('B008I1XLDQ', 'B0029XDZIK', 0.080055898799054517),
#  ('B008I1XLDQ', 'B007TGDXMU', 0.064492115001069508),
#  ('B008I1XLDQ', 'B0051SU0OW', 0.059106706451599232),
#  ('B008I1XLDQ', 'B005HGAVD8', 0.011485114710663923),
#  ('B008I1XLDQ', 'B00DS842HS', 0.0),
#  ('B008I1XLDQ', 'B0031JK95S', 0.0),
#  ('B008I1XLDQ', 'B001EO5Q64', 0.0),
#  ('B008I1XLDQ', 'B00BI8OG2Q', 0.0),
#  ('B008I1XLDQ', 'B001D05RWC', 0.0),
#  ('B008I1XLDQ', 'B00032G1S0', 0.0),
#  ('B008I1XLDQ', 'B000LKXRNQ', 0.0),
#  ('B008I1XLDQ', 'B000PDWBKO', 0.0),
#  ('B008I1XLDQ', 'B003Z6W32E', 0.0),
#  ('B008I1XLDQ', 'B000GAT6NG', 0.0),
#  ('B008I1XLDQ', 'B0029AG878', 0.0),
#  ('B008I1XLDQ', 'B00C1LXBFC', 0.0),
#  ('B008I1XLDQ', 'B000NMJWZO', 0.0),
#  ('B008I1XLDQ', 'B0034EDLS2', 0.0),
#  ('B008I1XLDQ', 'B003OGKCDC', 0.0),
#  ('B008I1XLDQ', 'B00014CZP8', 0.0),
#  ('B008I1XLDQ', 'B0043WOANY', 0.0),
#  ('B008I1XLDQ', 'B000EVOSE4', 0.0),
#  ('B008I1XLDQ', 'B000Z93FQC', 0.0),
#  ('B008I1XLDQ', 'B004P4POZ8', 0.0),
#  ('B008I1XLDQ', 'B0098WV8F2', 0.0),
#  ('B008I1XLDQ', 'B00BP36RTY', 0.0),
#  ('B008I1XLDQ', 'B001E0HT2W', 0.0),
#  ('B008I1XLDQ', 'B004391DK0', 0.0),
#  ('B008I1XLDQ', 'B00GW3KSPQ', 0.0),
#  ('B008I1XLDQ', 'B003QDRJXY', 0.0),
#  ('B008I1XLDQ', 'B001ELL60W', 0.0),
#  ('B008I1XLDQ', 'B000UP8QQ0', 0.0),
#  ('B008I1XLDQ', 'B001E5E2RC', 0.0),
#  ('B008I1XLDQ', 'B00DDT116M', 0.0),
#  ('B008I1XLDQ', 'B001BM4JLC', 0.0),
#  ('B008I1XLDQ', 'B000SDIO3E', 0.0),
#  ('B008I1XLDQ', 'B001CGTN1I', 0.0),
#  ('B008I1XLDQ', 'B0032RPLSY', 0.0),
#  ('B008I1XLDQ', 'B0012C2GFM', 0.0),
#  ('B008I1XLDQ', 'B00CVTFT6I', 0.0),
#  ('B008I1XLDQ', 'B00ABKWSTA', 0.0),
#  ('B008I1XLDQ', 'B003FDC2I2', 0.0),
#  ('B008I1XLDQ', 'B000UUWECC', 0.0),
#  ('B008I1XLDQ', 'B00HK6FGIS', 0.0),
#  ('B008I1XLDQ', 'B00DSQZNEG', 0.0),
#  ('B008I1XLDQ', 'B000VK08OC', 0.0),
#  ('B008I1XLDQ', 'B000K8WVYA', 0.0),
#  ('B008I1XLDQ', 'B000H7LVKY', 0.0),
#  ('B008I1XLDQ', 'B001XUIGG6', 0.0),
#  ('B008I1XLDQ', 'B0008D6WBA', 0.0),
#  ('B008I1XLDQ', 'B000E1D7RS', -0.015113689741754184),
#  ('B008I1XLDQ', 'B000VK4DXO', -0.076249285166302333),
#  ('B008I1XLDQ', 'B003KRHDMI', -0.094151874266766564),
#  ('B008I1XLDQ', 'B003Z6ZGZU', -0.099339926779878324),
#  ('B008I1XLDQ', 'B006IOKA9S', -0.10146346292135015),
#  ('B008I1XLDQ', 'B007N04AF6', -0.13483997249264842),
#  ('B008I1XLDQ', 'B0010UOGWM', -0.20796156885780728),
#  ('B008I1XLDQ', 'B005K0L2U2', -0.30606668389141989),
#  ('B008I1XLDQ', 'B009AH7OU8', -0.34921514788478925),
#  ('B008I1XLDQ', 'B000GFYRHG', -0.37518323968843348),
#  ('B008I1XLDQ', 'B0026ZYZ7Q', -0.38786793183404766),
#  ('B008I1XLDQ', 'B000EVQWKC', -0.5),
#  ('B008I1XLDQ', 'B0010YA02S', -0.57735026918962584),
#  ('B008I1XLDQ', 'B000ENUC3S', -1.0),
#  ('B008I1XLDQ', 'B0014WYXQK', -1.0)]
